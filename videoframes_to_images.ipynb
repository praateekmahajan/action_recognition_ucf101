# %%
# %matplotlib inline
import io
import base64
from IPython.display import HTML
import matplotlib.pyplot as plt
from PIL import Image
# video = io.open('test.avi', 'r+b').read()
FOLDER = "data/"
# cv2.imshow(video)

# %%
import skvideo.io
from pprint import pprint
vid = skvideo.io.vread("data/UCF101/v_ApplyEyeMakeup_g01_c02.avi")
# %timeit meta = skvideo.io.ffprobe("test.avi")

# %timeit frames = vid.shape[0]
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-019ecef690f0> in <module>()
# ----> 1 import skvideo.io
#       2 from pprint import pprint
#       3 vid = skvideo.io.vread("data/UCF101/v_ApplyEyeMakeup_g01_c02.avi")
#       4 # %timeit meta = skvideo.io.ffprobe("test.avi")
#       5
#
# ImportError: No module named skvideo.io

# %%
with open(FOLDER+"trainlist01.txt") as f:
    content = f.readlines()
# you may also want to remove whitespace characters like `\n` at the end of each line
content = [x.strip().split(" ") for x in content]

# %%
sample = content[:5]

# %%
for video,label in sample:
    videon = video.split("/")[1]
    vid = skvideo.io.vread(FOLDER + "UCF101/" + videon)
    frames = vid.shape[0]
    index = 0
#     print label
    meta = skvideo.io.ffprobe(FOLDER + "UCF101/" + videon)
    toextract = int(frames/(float(meta['video']['@duration'])*2))
    for frame in xrange(0,frames,toextract):
#         print frame, frames, videon
        im = Image.fromarray(vid[frame])
        filename = videon.split(".avi")[0]+"_"+str(index)+".jpg"
        im.save(FOLDER + "UCF101_images/" + filename)
        index += 1
        print filename
        with open(FOLDER + "image_train1.txt", "a") as myfile:
            myfile.write(filename + " " + label +"\n")
# Out:
# v_ApplyEyeMakeup_g08_c01_0.jpg
# v_ApplyEyeMakeup_g08_c01_1.jpg
# v_ApplyEyeMakeup_g08_c01_2.jpg
# v_ApplyEyeMakeup_g08_c01_3.jpg
# v_ApplyEyeMakeup_g08_c01_4.jpg
# v_ApplyEyeMakeup_g08_c01_5.jpg
# v_ApplyEyeMakeup_g08_c01_6.jpg
# v_ApplyEyeMakeup_g08_c01_7.jpg
# v_ApplyEyeMakeup_g08_c01_8.jpg
# v_ApplyEyeMakeup_g08_c01_9.jpg
# v_ApplyEyeMakeup_g08_c02_0.jpg
# v_ApplyEyeMakeup_g08_c02_1.jpg
# v_ApplyEyeMakeup_g08_c02_2.jpg
# v_ApplyEyeMakeup_g08_c02_3.jpg
# v_ApplyEyeMakeup_g08_c02_4.jpg
# v_ApplyEyeMakeup_g08_c02_5.jpg
# v_ApplyEyeMakeup_g08_c02_6.jpg
# v_ApplyEyeMakeup_g08_c02_7.jpg
# v_ApplyEyeMakeup_g08_c02_8.jpg
# v_ApplyEyeMakeup_g08_c02_9.jpg
# v_ApplyEyeMakeup_g08_c03_0.jpg
# v_ApplyEyeMakeup_g08_c03_1.jpg
# v_ApplyEyeMakeup_g08_c03_2.jpg
# v_ApplyEyeMakeup_g08_c03_3.jpg
